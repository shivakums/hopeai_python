# %%
#from <fileName> import <ClassName>
from multipleFunctions import multipleFunction

# %%
#ClassName.FunctionName
multipleFunction.BMI()
# Out:
# Enter the BMI Index: 12
# Underweight
# 'Underweight'

# %%
#ClassName.FunctionName
multipleFunction.OddEven()
# Out:
# Enter the number: 23
# Odd Number
# 'Odd number'

# %%
#ClassName.FunctionName
multipleFunction.AgeCategory()
# Out:
# Enter age: 23
# Adult
# 'Adult1'

# %%
multipleFunction.addition(5,3)
# Out:
# 8

# %%
multipleFunction.subtraction(10,3)
# Out:
# 7
