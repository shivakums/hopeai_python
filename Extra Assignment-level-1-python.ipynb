# %%
# Print Statement
print("Hope AI")
# Out:
# Hope AI

# %%
# By Input
institute_name = input("Enter your institute name ?:")
print(institute_name)
# Out:
# Enter your institute name ?: Hope AI
# Hope AI

# %%
# By Input
name = input("Enter your name:")
age = input("Enter your age:")
school = input("Enter your School:")
degree = input("Enter your drgree:")
# Out:
# Enter your name: Sivakumar SY
# Enter your age: 55
# Enter your School: St Xaviers
# Enter your drgree: B Sc

# %%
# Addition
a = 43
b = 34
add = a+b
print("a=",a)
print("b=",b)
print("add=",add)
# Out:
# a= 43
# b= 34
# add= 77

# %%
# Subtraction
a = 43
b = 34
sub = a - b
print("a=",a)
print("b=",b)
print("sub=",sub)
# Out:
# a= 43
# b= 34
# sub= 9

# %%
# Multiply
a = 63
b = 97
mul = a * b
print("a=",a)
print("b=",b)
print("mul=",mul)
# Out:
# a= 63
# b= 97
# mul= 6111

# %%
# Division
a = 76
b = 31
div =float(a / b)
print("a=",a)
print("b=",b)
print("Float Div=",div)
# Out:
# a= 76
# b= 31
# Float Div= 2.4516129032258065

# %%
# Floar Division
a = 76
b = 31
div = int(a / b)
print("a=",a)
print("b=",b)
print("Floor Div=",div)
# Out:
# a= 76
# b= 31
# Floor Div= 2

# %%
# Modulo
a = 76
b = 31
mod = (a % b)
print("a=",a)
print("b=",b)
print("Modulo=",mod)
# Out:
# a= 76
# b= 31
# Modulo= 14

# %%
#POwer
a = 4
b = 4
power = 4 ** 4
print("a=",a)
print("b=",b)
print("Power",power)
# Out:
# a= 4
# b= 4
# Power 256
